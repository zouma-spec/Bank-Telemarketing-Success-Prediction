# %% [markdown]
# ## Distribution of target data: no vs. yes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ROC curve of Baseline KNN, Logistic, Decision Tree, Random Forest

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Precision-Recall curve of Baseline KNN, Logistic, Decision Tree, Random Forest
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Random Forest Report
# ![Screen%20Shot%202022-08-03%20at%2014.36.35.png](attachment:Screen%20Shot%202022-08-03%20at%2014.36.35.png)

# %% [markdown]
# ### Confusion Matrix
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Feature importance in Random Forest model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  ## Next step: Handle Class imbalance; Ensembling
